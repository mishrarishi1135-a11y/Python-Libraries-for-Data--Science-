# %%
# series with python functionalities
import numpy as np
import pandas as pd
df = pd.read_csv("../datasets/subs.csv")
series = df.squeeze()
print(series)

# %%
print(len(series))

# %%
print(type(series))
