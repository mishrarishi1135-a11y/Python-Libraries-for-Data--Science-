# %%
# Categorical estimate plot --> for measure central tendency ( Bar plot, point plot and count plot)
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Bar plot
sns.barplot(data=tips, x='sex', y='total_bill')

# when there are multiple observation in each category, it also uses bootstrapping to compute a confidence interval around the estimate, which is plotted using error bars.
# This black stick is 'error bars' and it create when value of x is repeat.
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# also we add hue parameter
sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# If you want to remove error bars then use 'ci =none'
sns.barplot(data=tips, x='sex',y='total_bill', ci=None)
# Out:
# C:\Users\Anuj Mishra\AppData\Local\Temp\ipykernel_26164\672050328.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tips, x='sex',y='total_bill', ci=None)
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# For standard deviation of total bill then we use estimator
import numpy as np
sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker', estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# Point plot
sns.pointplot(data=tips, x='sex', y='total_bill', hue='smoker',estimator=np.min)
# Here we connect the bars.(connect the all error bars)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='sex', y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x='sex', y='total_bill')
# It connect the error bars.
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# Count plot -> a special case for the bar plot is when you want to show the number of observation in each category rather than computing a statistics for a second variable.
# This is similar to a histogram over a categorical, rather than quantitative variable.
sns.countplot(data=tips, x='sex')
# It tells the male count and female count.
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips, x='sex', hue='day')
# Basically it's a histogram.
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Faceting using cat plot
sns.catplot(data=tips,x='sex', y='total_bill',col='smoker', kind='box')

# %%
# Here, we complete the categorical plot. Thank You!
